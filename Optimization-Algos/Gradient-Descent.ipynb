# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import random
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
def func(x,y):
    """
    Function to represent the function
    """
    return 2*pow(x,4)+pow(y,4)-2*pow(x,2)-2*pow(y,2)+4*math.sin(x*y)+5

# %%
func(4,5) # sanity check
# Out:
# 1063.6517810029104

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
x = np.linspace(-1.5, 1.5, 30)
y = np.linspace(-1.5, 1.5, 30)

X, Y = np.meshgrid(x, y)
zs = np.array([func(x,y) for x,y in zip(np.ravel(X), np.ravel(Y))])
Z = zs.reshape(X.shape)

# %%
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_title('surface');

# %%
# Out:
# array([[14.29979279, 13.49033153, 12.77853747, ...,  4.9660697 ,
#          5.87286253,  6.90669347],
#        [14.13232528, 13.29929697, 12.56432921, ...,  4.50888972,
#          5.39308329,  6.40374053],
#        [13.99943747, 13.14323546, 12.38564608, ...,  4.12167004,
#          4.98395392,  5.97198954],
#        ...,
#        [ 6.70706345,  5.60788972,  4.64176379, ..., 11.54847683,
#         12.23764871, 13.01714778],
#        [ 7.09376253,  5.97198954,  4.98395392, ..., 11.71755496,
#         12.38564608, 13.14323546],
#        [ 7.54868722,  6.40374053,  5.39308329, ..., 11.91814778,
#         12.56432921, 13.29929697]])
